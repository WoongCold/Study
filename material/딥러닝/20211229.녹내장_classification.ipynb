#   inflating: glaucoma/valid/normal/659.png
#   inflating: glaucoma/valid/normal/660.png
#   inflating: glaucoma/valid/normal/661.png
#   inflating: glaucoma/valid/normal/662.png
#   inflating: glaucoma/valid/normal/663.png
#   inflating: glaucoma/valid/normal/664.png
#   inflating: glaucoma/valid/normal/665.png
#   inflating: glaucoma/valid/normal/666.png
#   inflating: glaucoma/valid/normal/667.png
#   inflating: glaucoma/valid/normal/668.png
#   inflating: glaucoma/valid/normal/669.png
#   inflating: glaucoma/valid/normal/670.png
#   inflating: glaucoma/valid/normal/671.png
#   inflating: glaucoma/valid/normal/672.png
#   inflating: glaucoma/valid/normal/673.png
#   inflating: glaucoma/valid/normal/674.png
#   inflating: glaucoma/valid/normal/675.png
#   inflating: glaucoma/valid/normal/676.png
#   inflating: glaucoma/valid/normal/677.png
#   inflating: glaucoma/valid/normal/678.png
#   inflating: glaucoma/valid/normal/679.png
#   inflating: glaucoma/valid/normal/680.png
#   inflating: glaucoma/valid/normal/681.png
#   inflating: glaucoma/valid/normal/682.png
#   inflating: glaucoma/valid/normal/683.png
#   inflating: glaucoma/valid/normal/684.png
#   inflating: glaucoma/valid/normal/685.png
#   inflating: glaucoma/valid/normal/686.png
#   inflating: glaucoma/valid/normal/687.png
#   inflating: glaucoma/valid/normal/688.png
#   inflating: glaucoma/valid/normal/689.png
#   inflating: glaucoma/valid/normal/690.png
#   inflating: glaucoma/valid/normal/691.png
#   inflating: glaucoma/valid/normal/692.png
#   inflating: glaucoma/valid/normal/693.png
#   inflating: glaucoma/valid/normal/694.png
#   inflating: glaucoma/valid/normal/695.png
#   inflating: glaucoma/valid/normal/696.png
#   inflating: glaucoma/valid/normal/697.png
#   inflating: glaucoma/valid/normal/698.png
#   inflating: glaucoma/valid/normal/699.png
#   inflating: glaucoma/valid/normal/700.png
#   inflating: glaucoma/valid/normal/701.png
#   inflating: glaucoma/valid/normal/702.png
#   inflating: glaucoma/valid/normal/703.png
#   inflating: glaucoma/valid/normal/704.png
#   inflating: glaucoma/valid/normal/705.png
#   inflating: glaucoma/valid/normal/706.png
#   inflating: glaucoma/valid/normal/707.png
#   inflating: glaucoma/valid/normal/708.png
#   inflating: glaucoma/valid/normal/709.png
#   inflating: glaucoma/valid/normal/710.png

# %% [markdown]
# # 전이 학습 시도

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
conv_layers.trainable = False

model = keras.Sequential()

model.add(conv_layers)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      vertical_flip=False,
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=10
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()


loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31793152/31790344 [==============================] - 1s 0us/step
# 31801344/31790344 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 7, 7, 1408)       7768569
#
#  flatten (Flatten)           (None, 68992)             0
#
#  dense (Dense)               (None, 256)               17662208
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 25,432,572
# Trainable params: 17,663,491
# Non-trainable params: 7,769,081
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/10
# 20/20 [==============================] - 39s 1s/step - loss: 1.0078 - acc: 0.6870 - val_loss: 3.0881 - val_acc: 0.5500
# Epoch 2/10
# 20/20 [==============================] - 19s 925ms/step - loss: 0.5933 - acc: 0.7545 - val_loss: 3.9152 - val_acc: 0.4375
# Epoch 3/10
# 20/20 [==============================] - 19s 954ms/step - loss: 0.5078 - acc: 0.7935 - val_loss: 2.5126 - val_acc: 0.5562
# Epoch 4/10
# 20/20 [==============================] - 19s 963ms/step - loss: 0.5174 - acc: 0.7992 - val_loss: 2.6813 - val_acc: 0.4375
# Epoch 5/10
# 20/20 [==============================] - 19s 923ms/step - loss: 0.4661 - acc: 0.8033 - val_loss: 2.2267 - val_acc: 0.4500
# Epoch 6/10
# 20/20 [==============================] - 19s 962ms/step - loss: 0.4043 - acc: 0.8407 - val_loss: 1.5431 - val_acc: 0.4688
# Epoch 7/10
# 20/20 [==============================] - 19s 923ms/step - loss: 0.3895 - acc: 0.8463 - val_loss: 2.1941 - val_acc: 0.3625
# Epoch 8/10
# 20/20 [==============================] - 19s 923ms/step - loss: 0.3764 - acc: 0.8504 - val_loss: 1.8423 - val_acc: 0.4437
# Epoch 9/10
# 20/20 [==============================] - 19s 950ms/step - loss: 0.3508 - acc: 0.8593 - val_loss: 1.3326 - val_acc: 0.5562
# Epoch 10/10
# 20/20 [==============================] - 19s 929ms/step - loss: 0.3332 - acc: 0.8675 - val_loss: 2.4576 - val_acc: 0.4437
# 3/3 [==============================] - 1s 283ms/step - loss: 2.7541 - acc: 0.3571
# loss= 2.754075765609741
# acc= 0.3571428656578064
# label category index = 2.0
# predicted category index = 2
# predicted category name = normal

# %% [markdown]
# # 전이학습 인데 conv도 학습

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
conv_layers.trainable = True   # <-----------------------

model = keras.Sequential()

model.add(conv_layers)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      vertical_flip=False,
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=10
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()


loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 7, 7, 1408)       7768569
#
#  flatten_1 (Flatten)         (None, 68992)             0
#
#  dense_2 (Dense)             (None, 256)               17662208
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_3 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 25,432,572
# Trainable params: 25,364,485
# Non-trainable params: 68,087
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/10
# 20/20 [==============================] - 51s 1s/step - loss: 0.9600 - acc: 0.7065 - val_loss: 1.8677 - val_acc: 0.5312
# Epoch 2/10
# 20/20 [==============================] - 24s 1s/step - loss: 0.5602 - acc: 0.7813 - val_loss: 1.3412 - val_acc: 0.4750
# Epoch 3/10
# 20/20 [==============================] - 23s 1s/step - loss: 0.3931 - acc: 0.8431 - val_loss: 4.4837 - val_acc: 0.5000
# Epoch 4/10
# 20/20 [==============================] - 23s 1s/step - loss: 0.3541 - acc: 0.8520 - val_loss: 4.0046 - val_acc: 0.3750
# Epoch 5/10
# 20/20 [==============================] - 23s 1s/step - loss: 0.3176 - acc: 0.8715 - val_loss: 2.0468 - val_acc: 0.3500
# Epoch 6/10
# 20/20 [==============================] - 23s 1s/step - loss: 0.2826 - acc: 0.9073 - val_loss: 4.0923 - val_acc: 0.5125
# Epoch 7/10
# 20/20 [==============================] - 23s 1s/step - loss: 0.2639 - acc: 0.9033 - val_loss: 2.2304 - val_acc: 0.5688
# Epoch 8/10
# 20/20 [==============================] - 23s 1s/step - loss: 0.1970 - acc: 0.9260 - val_loss: 3.3887 - val_acc: 0.5562
# Epoch 9/10
# 20/20 [==============================] - 23s 1s/step - loss: 0.1800 - acc: 0.9325 - val_loss: 3.3769 - val_acc: 0.5125
# Epoch 10/10
# 20/20 [==============================] - 23s 1s/step - loss: 0.1580 - acc: 0.9398 - val_loss: 1.1557 - val_acc: 0.6938
# 3/3 [==============================] - 1s 172ms/step - loss: 1.7461 - acc: 0.5909
# loss= 1.7461448907852173
# acc= 0.5909090638160706
# label category index = 1.0
# predicted category index = 0
# predicted category name = advanced

# %% [markdown]
# # vanila CNN으로

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization, Conv2D, MaxPooling2D, Input
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

# conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))   # <-----------------------
# conv_layers.trainable = True   # <-----------------------

model = keras.Sequential()

# model.add(conv_layers)
model.add(Input((224,224,3)))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(128, (3,3), padding='same'))
model.add(Conv2D(128, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(256, (3,3), padding='same'))
model.add(Conv2D(256, (3,3), padding='same'))
model.add(Conv2D(256, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      vertical_flip=False,
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=10
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()


loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 64)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 256)               6422784
#
#  batch_normalization_2 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_5 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 21,139,267
# Trainable params: 21,138,755
# Non-trainable params: 512
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/10
# 20/20 [==============================] - 26s 1s/step - loss: 0.9197 - acc: 0.6593 - val_loss: 13.4117 - val_acc: 0.3125
# Epoch 2/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.6657 - acc: 0.7244 - val_loss: 3.5946 - val_acc: 0.4062
# Epoch 3/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.6478 - acc: 0.7163 - val_loss: 1.1512 - val_acc: 0.5312
# Epoch 4/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.6830 - acc: 0.7057 - val_loss: 1.3866 - val_acc: 0.4875
# Epoch 5/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.6542 - acc: 0.7187 - val_loss: 3.2831 - val_acc: 0.5750
# Epoch 6/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.5763 - acc: 0.7618 - val_loss: 9.1884 - val_acc: 0.3375
# Epoch 7/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.8850 - acc: 0.6626 - val_loss: 1.2593 - val_acc: 0.3562
# Epoch 8/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.5982 - acc: 0.7488 - val_loss: 6.2175 - val_acc: 0.4250
# Epoch 9/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.5612 - acc: 0.7577 - val_loss: 4.3171 - val_acc: 0.3625
# Epoch 10/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.6008 - acc: 0.7374 - val_loss: 10.7821 - val_acc: 0.4500
# 3/3 [==============================] - 1s 448ms/step - loss: 14.0648 - acc: 0.3636
# loss= 14.064811706542969
# acc= 0.3636363744735718
# label category index = 2.0
# predicted category index = 0
# predicted category name = advanced

# %% [markdown]
# # learning rate 작게

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization, Conv2D, MaxPooling2D, Input
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

# conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# conv_layers.trainable = True

model = keras.Sequential()

# model.add(conv_layers)
model.add(Input((224,224,3)))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(128, (3,3), padding='same'))
model.add(Conv2D(128, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(256, (3,3), padding='same'))
model.add(Conv2D(256, (3,3), padding='same'))
model.add(Conv2D(256, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

import tensorflow
optimizer = tensorflow.keras.optimizers.RMSprop(learning_rate=0.0001)   # <-----------------------
# model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['acc'])   # <-----------------------
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      vertical_flip=False,
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=10
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()


loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_14 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_5 (MaxPooling  (None, 112, 112, 64)     0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_16 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_6 (MaxPooling  (None, 56, 56, 128)      0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_18 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_19 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_7 (MaxPooling  (None, 28, 28, 256)      0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 512)      0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_9 (MaxPooling  (None, 7, 7, 512)        0
#  2D)
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  dense_6 (Dense)             (None, 256)               6422784
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_7 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 21,139,267
# Trainable params: 21,138,755
# Non-trainable params: 512
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/10
# 20/20 [==============================] - 23s 1s/step - loss: 1.1630 - acc: 0.5772 - val_loss: 36.0562 - val_acc: 0.3125
# Epoch 2/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.8046 - acc: 0.6797 - val_loss: 2.0445 - val_acc: 0.3500
# Epoch 3/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.6796 - acc: 0.7374 - val_loss: 1.6657 - val_acc: 0.5000
# Epoch 4/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.7056 - acc: 0.7081 - val_loss: 26.7278 - val_acc: 0.3000
# Epoch 5/10
# 20/20 [==============================] - 20s 996ms/step - loss: 0.7999 - acc: 0.6992 - val_loss: 3.2911 - val_acc: 0.4500
# Epoch 6/10
# 20/20 [==============================] - 20s 1s/step - loss: 0.7025 - acc: 0.7252 - val_loss: 19.8224 - val_acc: 0.3125
# Epoch 7/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.7436 - acc: 0.7057 - val_loss: 2.8754 - val_acc: 0.3875
# Epoch 8/10
# 20/20 [==============================] - 20s 1s/step - loss: 0.7165 - acc: 0.6927 - val_loss: 5.4988 - val_acc: 0.5000
# Epoch 9/10
# 20/20 [==============================] - 20s 1s/step - loss: 0.7030 - acc: 0.6976 - val_loss: 1.5388 - val_acc: 0.4938
# Epoch 10/10
# 20/20 [==============================] - 20s 996ms/step - loss: 0.7061 - acc: 0.7252 - val_loss: 15.7255 - val_acc: 0.3125
# 3/3 [==============================] - 1s 163ms/step - loss: 14.5579 - acc: 0.3052
# loss= 14.55793285369873
# acc= 0.30519479513168335
# label category index = 2.0
# predicted category index = 0
# predicted category name = advanced

# %%
train_data_generator.batch_size=1000
batch_x, batch_y = train_data_generator.next()
print(batch_x.shape)
print(batch_y.shape)
# Out:
# (1000, 224, 224, 3)
# (1000,)

# %%
plt.hist(batch_y, bins=3)
plt.show()

# %% [markdown]
# # optimizer를 Adam으로

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization, Conv2D, MaxPooling2D, Input
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

# conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# conv_layers.trainable = True

model = keras.Sequential()

# model.add(conv_layers)
model.add(Input((224,224,3)))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(128, (3,3), padding='same'))
model.add(Conv2D(128, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(256, (3,3), padding='same'))
model.add(Conv2D(256, (3,3), padding='same'))
model.add(Conv2D(256, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(Conv2D(512, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

import tensorflow
optimizer = tensorflow.keras.optimizers.Adam(learning_rate=0.0001)   # <-----------------------
# model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      vertical_flip=False,
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=10
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()


loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_39 (Conv2D)          (None, 224, 224, 64)      1792
#
#  conv2d_40 (Conv2D)          (None, 224, 224, 64)      36928
#
#  max_pooling2d_15 (MaxPoolin  (None, 112, 112, 64)     0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 112, 112, 128)     73856
#
#  conv2d_42 (Conv2D)          (None, 112, 112, 128)     147584
#
#  max_pooling2d_16 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 56, 56, 256)       295168
#
#  conv2d_44 (Conv2D)          (None, 56, 56, 256)       590080
#
#  conv2d_45 (Conv2D)          (None, 56, 56, 256)       590080
#
#  max_pooling2d_17 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 28, 28, 512)       1180160
#
#  conv2d_47 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  conv2d_48 (Conv2D)          (None, 28, 28, 512)       2359808
#
#  max_pooling2d_18 (MaxPoolin  (None, 14, 14, 512)      0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_50 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_51 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_19 (MaxPoolin  (None, 7, 7, 512)        0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 25088)             0
#
#  dense_10 (Dense)            (None, 256)               6422784
#
#  batch_normalization_5 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_11 (Dense)            (None, 3)                 771
#
# =================================================================
# Total params: 21,139,267
# Trainable params: 21,138,755
# Non-trainable params: 512
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/10
# 20/20 [==============================] - 22s 1s/step - loss: 0.9038 - acc: 0.6634 - val_loss: 4.9934 - val_acc: 0.4500
# Epoch 2/10
# 20/20 [==============================] - 20s 1s/step - loss: 0.6889 - acc: 0.7211 - val_loss: 6.4931 - val_acc: 0.4375
# Epoch 3/10
# 20/20 [==============================] - 20s 1s/step - loss: 0.7146 - acc: 0.7268 - val_loss: 8.4467 - val_acc: 0.3125
# Epoch 4/10
# 20/20 [==============================] - 20s 1s/step - loss: 0.6496 - acc: 0.7374 - val_loss: 9.0024 - val_acc: 0.6750
# Epoch 5/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.6469 - acc: 0.7463 - val_loss: 6.7267 - val_acc: 0.3125
# Epoch 6/10
# 20/20 [==============================] - 21s 1s/step - loss: 0.6268 - acc: 0.7463 - val_loss: 1.0534 - val_acc: 0.6500
# Epoch 7/10
# 20/20 [==============================] - 20s 1s/step - loss: 0.6658 - acc: 0.7268 - val_loss: 2.9921 - val_acc: 0.3375
# Epoch 8/10
# 20/20 [==============================] - 20s 996ms/step - loss: 0.6261 - acc: 0.7463 - val_loss: 2.5178 - val_acc: 0.3250
# Epoch 9/10
# 20/20 [==============================] - 20s 991ms/step - loss: 0.5964 - acc: 0.7667 - val_loss: 2.4140 - val_acc: 0.3125
# Epoch 10/10
# 20/20 [==============================] - 20s 988ms/step - loss: 0.5810 - acc: 0.7699 - val_loss: 2.9526 - val_acc: 0.2500
# 3/3 [==============================] - 1s 162ms/step - loss: 3.3940 - acc: 0.2922
# loss= 3.394014358520508
# acc= 0.2922077775001526
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8951da6c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# label category index = 1.0
# predicted category index = 0
# predicted category name = advanced

# %% [markdown]
# # epoch 더 많이 학습

# %%
history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=40   # <-----------------------
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()


loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Epoch 1/40
# 20/20 [==============================] - 20s 1s/step - loss: 0.5794 - acc: 0.7691 - val_loss: 2.1166 - val_acc: 0.2875
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()

# %% [markdown]
# # Conv 레이어들 작게 조정

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization, Conv2D, MaxPooling2D, Input
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

# conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# conv_layers.trainable = True

model = keras.Sequential()

# model.add(conv_layers)
model.add(Input((224,224,3)))
model.add(Conv2D(32, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(32, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(32, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(32, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(32, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Conv2D(128, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(128, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(128, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Conv2D(128, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(128, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(128, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

import tensorflow
optimizer = tensorflow.keras.optimizers.Adam(learning_rate=0.0001)
# model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      vertical_flip=False,
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=10
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()

loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_52 (Conv2D)          (None, 224, 224, 32)      896
#
#  conv2d_53 (Conv2D)          (None, 224, 224, 32)      9248
#
#  conv2d_54 (Conv2D)          (None, 224, 224, 32)      9248
#
#  max_pooling2d_20 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_55 (Conv2D)          (None, 112, 112, 32)      9248
#
#  conv2d_56 (Conv2D)          (None, 112, 112, 32)      9248
#
#  conv2d_57 (Conv2D)          (None, 112, 112, 32)      9248
#
#  max_pooling2d_21 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_58 (Conv2D)          (None, 56, 56, 64)        18496
#
#  conv2d_59 (Conv2D)          (None, 56, 56, 64)        36928
#
#  conv2d_60 (Conv2D)          (None, 56, 56, 64)        36928
#
#  max_pooling2d_22 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_61 (Conv2D)          (None, 28, 28, 128)       73856
#
#  conv2d_62 (Conv2D)          (None, 28, 28, 128)       147584
#
#  conv2d_63 (Conv2D)          (None, 28, 28, 128)       147584
#
#  max_pooling2d_23 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_64 (Conv2D)          (None, 14, 14, 128)       147584
#
#  conv2d_65 (Conv2D)          (None, 14, 14, 128)       147584
#
#  conv2d_66 (Conv2D)          (None, 14, 14, 128)       147584
#
#  max_pooling2d_24 (MaxPoolin  (None, 7, 7, 128)        0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 6272)              0
#
#  dense_12 (Dense)            (None, 256)               1605888
#
#  batch_normalization_6 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_13 (Dense)            (None, 3)                 771
#
# =================================================================
# Total params: 2,558,947
# Trainable params: 2,558,435
# Non-trainable params: 512
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/10
# 20/20 [==============================] - 20s 908ms/step - loss: 0.8228 - acc: 0.6797 - val_loss: 1.8906 - val_acc: 0.6938
# Epoch 2/10
# 20/20 [==============================] - 18s 897ms/step - loss: 0.6814 - acc: 0.7341 - val_loss: 6.5419 - val_acc: 0.2875
# Epoch 3/10
# 20/20 [==============================] - 18s 899ms/step - loss: 0.7282 - acc: 0.7041 - val_loss: 2.1857 - val_acc: 0.6500
# Epoch 4/10
# 20/20 [==============================] - 18s 899ms/step - loss: 0.6677 - acc: 0.7268 - val_loss: 1.3971 - val_acc: 0.5875
# Epoch 5/10
# 20/20 [==============================] - 18s 898ms/step - loss: 0.6242 - acc: 0.7561 - val_loss: 1.4467 - val_acc: 0.5813
# Epoch 6/10
# 20/20 [==============================] - 18s 907ms/step - loss: 0.5889 - acc: 0.7650 - val_loss: 1.2853 - val_acc: 0.5813
# Epoch 7/10
# 20/20 [==============================] - 18s 905ms/step - loss: 0.6072 - acc: 0.7455 - val_loss: 1.9239 - val_acc: 0.3625
# Epoch 8/10
# 20/20 [==============================] - 18s 905ms/step - loss: 0.5719 - acc: 0.7764 - val_loss: 2.0668 - val_acc: 0.3187
# Epoch 9/10
# 20/20 [==============================] - 18s 907ms/step - loss: 0.5573 - acc: 0.7846 - val_loss: 1.3733 - val_acc: 0.4187
# Epoch 10/10
# 20/20 [==============================] - 18s 893ms/step - loss: 0.5605 - acc: 0.7797 - val_loss: 1.1086 - val_acc: 0.5250
# 3/3 [==============================] - 1s 223ms/step - loss: 1.4108 - acc: 0.4221
# loss= 1.41081964969635
# acc= 0.4220779240131378
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f895399ba70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# label category index = 2.0
# predicted category index = 0
# predicted category name = advanced

# %% [markdown]
# # Conv 더 작게

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization, Conv2D, MaxPooling2D, Input
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

# conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# conv_layers.trainable = True

model = keras.Sequential()

# model.add(conv_layers)
model.add(Input((224,224,3)))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(32, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(32, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(Conv2D(64, (3,3), padding='same'))   # <-----------------------
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

import tensorflow
optimizer = tensorflow.keras.optimizers.Adam(learning_rate=0.0001)
# model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      vertical_flip=False,
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=10
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()

loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_67 (Conv2D)          (None, 224, 224, 32)      896
#
#  conv2d_68 (Conv2D)          (None, 224, 224, 32)      9248
#
#  conv2d_69 (Conv2D)          (None, 224, 224, 32)      9248
#
#  max_pooling2d_25 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_70 (Conv2D)          (None, 112, 112, 32)      9248
#
#  conv2d_71 (Conv2D)          (None, 112, 112, 32)      9248
#
#  conv2d_72 (Conv2D)          (None, 112, 112, 32)      9248
#
#  max_pooling2d_26 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_73 (Conv2D)          (None, 56, 56, 64)        18496
#
#  conv2d_74 (Conv2D)          (None, 56, 56, 64)        36928
#
#  conv2d_75 (Conv2D)          (None, 56, 56, 64)        36928
#
#  max_pooling2d_27 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_76 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_77 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_78 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_28 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_79 (Conv2D)          (None, 14, 14, 64)        36928
#
#  conv2d_80 (Conv2D)          (None, 14, 14, 64)        36928
#
#  conv2d_81 (Conv2D)          (None, 14, 14, 64)        36928
#
#  max_pooling2d_29 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 3136)              0
#
#  dense_14 (Dense)            (None, 256)               803072
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_15 (Dense)            (None, 3)                 771
#
# =================================================================
# Total params: 1,165,923
# Trainable params: 1,165,411
# Non-trainable params: 512
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/10
# 20/20 [==============================] - 20s 927ms/step - loss: 0.8292 - acc: 0.6610 - val_loss: 7.6368 - val_acc: 0.3375
# Epoch 2/10
# 20/20 [==============================] - 18s 897ms/step - loss: 0.6393 - acc: 0.7325 - val_loss: 7.2491 - val_acc: 0.5000
# Epoch 3/10
# 20/20 [==============================] - 18s 895ms/step - loss: 0.6014 - acc: 0.7496 - val_loss: 2.7848 - val_acc: 0.5188
# Epoch 4/10
# 20/20 [==============================] - 18s 901ms/step - loss: 0.5934 - acc: 0.7618 - val_loss: 1.1370 - val_acc: 0.6250
# Epoch 5/10
# 20/20 [==============================] - 18s 902ms/step - loss: 0.5738 - acc: 0.7545 - val_loss: 1.1033 - val_acc: 0.4688
# Epoch 6/10
# 20/20 [==============================] - 18s 901ms/step - loss: 0.5521 - acc: 0.7667 - val_loss: 0.9060 - val_acc: 0.6187
# Epoch 7/10
# 20/20 [==============================] - 18s 897ms/step - loss: 0.5453 - acc: 0.7675 - val_loss: 1.3718 - val_acc: 0.5125
# Epoch 8/10
# 20/20 [==============================] - 18s 903ms/step - loss: 0.5212 - acc: 0.7821 - val_loss: 2.3916 - val_acc: 0.4187
# Epoch 9/10
# 20/20 [==============================] - 18s 899ms/step - loss: 0.5378 - acc: 0.7821 - val_loss: 1.4031 - val_acc: 0.4875
# Epoch 10/10
# 20/20 [==============================] - 18s 899ms/step - loss: 0.5229 - acc: 0.7740 - val_loss: 0.8575 - val_acc: 0.6500
# 3/3 [==============================] - 1s 167ms/step - loss: 1.0551 - acc: 0.5455
# loss= 1.0550774335861206
# acc= 0.5454545617103577
# label category index = 0.0
# predicted category index = 0
# predicted category name = advanced

# %% [markdown]
# # 사용하면 안될 preprocess를 제거하고 scaling

# %%
train_data_generator.batch_size=32
batch_x, batch_y = train_data_generator.next()
print(batch_x.shape)
print(batch_y.shape)

plt.hist(batch_x[0].flatten(), bins=1000)
plt.show()
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization, Conv2D, MaxPooling2D, Input
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

# conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# conv_layers.trainable = True

model = keras.Sequential()

# model.add(conv_layers)
model.add(Input((224,224,3)))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

import tensorflow
optimizer = tensorflow.keras.optimizers.Adam(learning_rate=0.0001)
# model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      vertical_flip=False,
      rescale=1/255.,   # <-----------------------
      # preprocessing_function=preprocessor   # <-----------------------
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      rescale=1/255.,   # <-----------------------
      # preprocessing_function=preprocessor   # <-----------------------
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      rescale=1/255.,   # <-----------------------
      # preprocessing_function=preprocessor   # <-----------------------
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=10
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()

loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_82 (Conv2D)          (None, 224, 224, 32)      896
#
#  conv2d_83 (Conv2D)          (None, 224, 224, 32)      9248
#
#  conv2d_84 (Conv2D)          (None, 224, 224, 32)      9248
#
#  max_pooling2d_30 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_85 (Conv2D)          (None, 112, 112, 32)      9248
#
#  conv2d_86 (Conv2D)          (None, 112, 112, 32)      9248
#
#  conv2d_87 (Conv2D)          (None, 112, 112, 32)      9248
#
#  max_pooling2d_31 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_88 (Conv2D)          (None, 56, 56, 64)        18496
#
#  conv2d_89 (Conv2D)          (None, 56, 56, 64)        36928
#
#  conv2d_90 (Conv2D)          (None, 56, 56, 64)        36928
#
#  max_pooling2d_32 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_91 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_92 (Conv2D)          (None, 28, 28, 64)        36928
#
#  conv2d_93 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_33 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_94 (Conv2D)          (None, 14, 14, 64)        36928
#
#  conv2d_95 (Conv2D)          (None, 14, 14, 64)        36928
#
#  conv2d_96 (Conv2D)          (None, 14, 14, 64)        36928
#
#  max_pooling2d_34 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 3136)              0
#
#  dense_16 (Dense)            (None, 256)               803072
#
#  batch_normalization_8 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_17 (Dense)            (None, 3)                 771
#
# =================================================================
# Total params: 1,165,923
# Trainable params: 1,165,411
# Non-trainable params: 512
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/10
# 20/20 [==============================] - 20s 926ms/step - loss: 0.7481 - acc: 0.7008 - val_loss: 0.9480 - val_acc: 0.5000
# Epoch 2/10
# 20/20 [==============================] - 18s 893ms/step - loss: 0.6227 - acc: 0.7488 - val_loss: 1.0553 - val_acc: 0.3438
# Epoch 3/10
# 20/20 [==============================] - 18s 898ms/step - loss: 0.5979 - acc: 0.7675 - val_loss: 1.0212 - val_acc: 0.5000
# Epoch 4/10
# 20/20 [==============================] - 18s 893ms/step - loss: 0.5756 - acc: 0.7805 - val_loss: 1.0086 - val_acc: 0.4625
# Epoch 5/10
# 20/20 [==============================] - 18s 899ms/step - loss: 0.5708 - acc: 0.7691 - val_loss: 1.0040 - val_acc: 0.5000
# Epoch 6/10
# 20/20 [==============================] - 18s 891ms/step - loss: 0.5814 - acc: 0.7618 - val_loss: 0.7756 - val_acc: 0.6750
# Epoch 7/10
# 20/20 [==============================] - 18s 890ms/step - loss: 0.5449 - acc: 0.7675 - val_loss: 0.7653 - val_acc: 0.7250
# Epoch 8/10
# 20/20 [==============================] - 18s 895ms/step - loss: 0.5101 - acc: 0.7902 - val_loss: 0.7603 - val_acc: 0.7125
# Epoch 9/10
# 20/20 [==============================] - 18s 887ms/step - loss: 0.4976 - acc: 0.8000 - val_loss: 1.1275 - val_acc: 0.4750
# Epoch 10/10
# 20/20 [==============================] - 18s 897ms/step - loss: 0.5033 - acc: 0.7870 - val_loss: 0.7501 - val_acc: 0.6938
# 3/3 [==============================] - 1s 166ms/step - loss: 0.9441 - acc: 0.5844
# loss= 0.944138765335083
# acc= 0.5844155550003052
# label category index = 0.0
# predicted category index = 0
# predicted category name = advanced

# %%
train_data_generator.batch_size=32
batch_x, batch_y = train_data_generator.next()
print(batch_x.shape)
print(batch_y.shape)

plt.hist(batch_x[0].flatten(), bins=1000)
plt.show()
# Out:
# (32, 224, 224, 3)
# (32,)

# %% [markdown]
# # Learning Rate 더 줄이고, epoch 수 많이

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization, Conv2D, MaxPooling2D, Input
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

# conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# conv_layers.trainable = True

model = keras.Sequential()

# model.add(conv_layers)
model.add(Input((224,224,3)))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

import tensorflow
optimizer = tensorflow.keras.optimizers.Adam(learning_rate=0.0001*0.1)  # <-----------------------
# model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      vertical_flip=False,
      rescale=1/255.,
      # preprocessing_function=preprocessor 
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      rescale=1/255.
      # preprocessing_function=preprocessor 
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      rescale=1/255., 
      # preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=40  # <-----------------------
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()

loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_97 (Conv2D)          (None, 224, 224, 32)      896
#
#  conv2d_98 (Conv2D)          (None, 224, 224, 32)      9248
#
#  conv2d_99 (Conv2D)          (None, 224, 224, 32)      9248
#
#  max_pooling2d_35 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_100 (Conv2D)         (None, 112, 112, 32)      9248
#
#  conv2d_101 (Conv2D)         (None, 112, 112, 32)      9248
#
#  conv2d_102 (Conv2D)         (None, 112, 112, 32)      9248
#
#  max_pooling2d_36 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_103 (Conv2D)         (None, 56, 56, 64)        18496
#
#  conv2d_104 (Conv2D)         (None, 56, 56, 64)        36928
#
#  conv2d_105 (Conv2D)         (None, 56, 56, 64)        36928
#
#  max_pooling2d_37 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_106 (Conv2D)         (None, 28, 28, 64)        36928
#
#  conv2d_107 (Conv2D)         (None, 28, 28, 64)        36928
#
#  conv2d_108 (Conv2D)         (None, 28, 28, 64)        36928
#
#  max_pooling2d_38 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_109 (Conv2D)         (None, 14, 14, 64)        36928
#
#  conv2d_110 (Conv2D)         (None, 14, 14, 64)        36928
#
#  conv2d_111 (Conv2D)         (None, 14, 14, 64)        36928
#
#  max_pooling2d_39 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 3136)              0
#
#  dense_18 (Dense)            (None, 256)               803072
#
#  batch_normalization_9 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_19 (Dense)            (None, 3)                 771
#
# =================================================================
# Total params: 1,165,923
# Trainable params: 1,165,411
# Non-trainable params: 512
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/40
# 20/20 [==============================] - 20s 921ms/step - loss: 0.8436 - acc: 0.6366 - val_loss: 1.0639 - val_acc: 0.5000
# Epoch 2/40
# 20/20 [==============================] - 18s 890ms/step - loss: 0.6590 - acc: 0.7455 - val_loss: 1.0448 - val_acc: 0.5188
# Epoch 3/40
# 20/20 [==============================] - 18s 888ms/step - loss: 0.6386 - acc: 0.7472 - val_loss: 1.0578 - val_acc: 0.5125
# Epoch 4/40
# 20/20 [==============================] - 18s 893ms/step - loss: 0.6141 - acc: 0.7480 - val_loss: 1.0193 - val_acc: 0.6938
# Epoch 5/40
# 20/20 [==============================] - 18s 896ms/step - loss: 0.5994 - acc: 0.7650 - val_loss: 1.0087 - val_acc: 0.6438
# Epoch 6/40
# 20/20 [==============================] - 18s 891ms/step - loss: 0.5904 - acc: 0.7756 - val_loss: 1.0298 - val_acc: 0.5000
# Epoch 7/40
# 20/20 [==============================] - 18s 897ms/step - loss: 0.5783 - acc: 0.7789 - val_loss: 1.0504 - val_acc: 0.4125
# Epoch 8/40
# 20/20 [==============================] - 18s 892ms/step - loss: 0.5621 - acc: 0.7854 - val_loss: 0.9663 - val_acc: 0.6750
# Epoch 9/40
# 20/20 [==============================] - 18s 893ms/step - loss: 0.5667 - acc: 0.7894 - val_loss: 1.0407 - val_acc: 0.4625
# Epoch 10/40
# 20/20 [==============================] - 18s 894ms/step - loss: 0.5582 - acc: 0.7683 - val_loss: 1.0085 - val_acc: 0.5312
# Epoch 11/40
# Epoch 32/40
# 20/20 [==============================] - 18s 878ms/step - loss: 0.4632 - acc: 0.8146 - val_loss: 0.9013 - val_acc: 0.5938
# Epoch 33/40
# 20/20 [==============================] - 18s 888ms/step - loss: 0.4628 - acc: 0.8106 - val_loss: 0.7006 - val_acc: 0.7063
# Epoch 34/40
# 20/20 [==============================] - 18s 891ms/step - loss: 0.4703 - acc: 0.8211 - val_loss: 0.8810 - val_acc: 0.6313
# Epoch 35/40
# 20/20 [==============================] - 18s 882ms/step - loss: 0.4628 - acc: 0.8171 - val_loss: 1.0502 - val_acc: 0.4750
# Epoch 36/40
# 20/20 [==============================] - 18s 886ms/step - loss: 0.4661 - acc: 0.8203 - val_loss: 0.7551 - val_acc: 0.6750
# Epoch 37/40
# 20/20 [==============================] - 18s 873ms/step - loss: 0.4603 - acc: 0.8195 - val_loss: 0.7795 - val_acc: 0.6500
# Epoch 38/40
# 20/20 [==============================] - 18s 879ms/step - loss: 0.4727 - acc: 0.8171 - val_loss: 0.7678 - val_acc: 0.6687
# Epoch 39/40
# 20/20 [==============================] - 17s 870ms/step - loss: 0.4654 - acc: 0.8171 - val_loss: 0.8720 - val_acc: 0.5750
# Epoch 40/40
# 20/20 [==============================] - 18s 877ms/step - loss: 0.4744 - acc: 0.8122 - val_loss: 1.0966 - val_acc: 0.5750
# 3/3 [==============================] - 1s 157ms/step - loss: 1.4597 - acc: 0.4675
# loss= 1.4596894979476929
# acc= 0.4675324559211731
# label category index = 2.0
# predicted category index = 2
# predicted category name = normal

# %% [markdown]
# # 데이터 증강 제거
#
# GPU를 거의 사용하지 못한다

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization, Conv2D, MaxPooling2D, Input
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

# conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# conv_layers.trainable = True

model = keras.Sequential()

# model.add(conv_layers)
model.add(Input((224,224,3)))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

import tensorflow
optimizer = tensorflow.keras.optimizers.Adam(learning_rate=0.0001*0.1)  # <-----------------------
# model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      # rotation_range=10,  # <-----------------------
      # width_shift_range=0.1,  # <-----------------------
      # height_shift_range=0.1,  # <-----------------------
      # horizontal_flip=True,  # <-----------------------
      # vertical_flip=False,  # <-----------------------
      rescale=1/255.,
      # preprocessing_function=preprocessor 
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      rescale=1/255.
      # preprocessing_function=preprocessor 
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      rescale=1/255., 
      # preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=40
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()

loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_112 (Conv2D)         (None, 224, 224, 32)      896
#
#  conv2d_113 (Conv2D)         (None, 224, 224, 32)      9248
#
#  conv2d_114 (Conv2D)         (None, 224, 224, 32)      9248
#
#  max_pooling2d_40 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_115 (Conv2D)         (None, 112, 112, 32)      9248
#
#  conv2d_116 (Conv2D)         (None, 112, 112, 32)      9248
#
#  conv2d_117 (Conv2D)         (None, 112, 112, 32)      9248
#
#  max_pooling2d_41 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_118 (Conv2D)         (None, 56, 56, 64)        18496
#
#  conv2d_119 (Conv2D)         (None, 56, 56, 64)        36928
#
#  conv2d_120 (Conv2D)         (None, 56, 56, 64)        36928
#
#  max_pooling2d_42 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_121 (Conv2D)         (None, 28, 28, 64)        36928
#
#  conv2d_122 (Conv2D)         (None, 28, 28, 64)        36928
#
#  conv2d_123 (Conv2D)         (None, 28, 28, 64)        36928
#
#  max_pooling2d_43 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_124 (Conv2D)         (None, 14, 14, 64)        36928
#
#  conv2d_125 (Conv2D)         (None, 14, 14, 64)        36928
#
#  conv2d_126 (Conv2D)         (None, 14, 14, 64)        36928
#
#  max_pooling2d_44 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 3136)              0
#
#  dense_20 (Dense)            (None, 256)               803072
#
#  batch_normalization_10 (Bat  (None, 256)              1024
#  chNormalization)
#
#  
# Epoch 18/40
# 20/20 [==============================] - 6s 292ms/step - loss: 0.4243 - acc: 0.8480 - val_loss: 0.8058 - val_acc: 0.6812
# Epoch 19/40
# 20/20 [==============================] - 6s 295ms/step - loss: 0.4048 - acc: 0.8455 - val_loss: 0.8663 - val_acc: 0.6313
# Epoch 20/40
# 20/20 [==============================] - 6s 299ms/step - loss: 0.3987 - acc: 0.8472 - val_loss: 0.8016 - val_acc: 0.6562
# Epoch 21/40
# 20/20 [==============================] - 6s 293ms/step - loss: 0.3825 - acc: 0.8610 - val_loss: 1.0202 - val_acc: 0.4875
# Epoch 22/40
# 20/20 [==============================] - 6s 307ms/step - loss: 0.3737 - acc: 0.8618 - val_loss: 0.8952 - val_acc: 0.6000
# Epoch 23/40
# 20/20 [==============================] - 6s 291ms/step - loss: 0.3772 - acc: 0.8602 - val_loss: 0.8847 - val_acc: 0.5813
# Epoch 24/40
# 20/20 [==============================] - 6s 290ms/step - loss: 0.3762 - acc: 0.8528 - val_loss: 0.8613 - val_acc: 0.6313
# Epoch 25/40
# 20/20 [==============================] - 6s 294ms/step - loss: 0.3575 - acc: 0.8683 - val_loss: 0.8716 - val_acc: 0.6250
# Epoch 26/40
# 20/20 [==============================] - 6s 294ms/step - loss: 0.3602 - acc: 0.8740 - val_loss: 0.9739 - val_acc: 0.5688
# Epoch 27/40
# 20/20 [==============================] - 6s 289ms/step - loss: 0.3452 - acc: 0.8732 - val_loss: 1.1506 - val_acc: 0.4812
# Epoch 28/40
# 20/20 [==============================] - 6s 295ms/step - loss: 0.3520 - acc: 0.8707 - val_loss: 0.9612 - val_acc: 0.5875
# Epoch 29/40
# 20/20 [==============================] - 6s 293ms/step - loss: 0.3411 - acc: 0.8797 - val_loss: 0.7727 - val_acc: 0.6687
# Epoch 30/40
# 20/20 [==============================] - 6s 294ms/step - loss: 0.3385 - acc: 0.8756 - val_loss: 0.9093 - val_acc: 0.6438
# Epoch 31/40
# 20/20 [==============================] - 6s 295ms/step - loss: 0.3333 - acc: 0.8756 - val_loss: 0.9147 - val_acc: 0.6125
# Epoch 32/40
# 20/20 [==============================] - 6s 305ms/step - loss: 0.3241 - acc: 0.8780 - val_loss: 1.0166 - val_acc: 0.5312
# Epoch 33/40
# 20/20 [==============================] - 6s 295ms/step - loss: 0.3224 - acc: 0.8756 - val_loss: 0.8817 - val_acc: 0.6000
# Epoch 34/40
# 20/20 [==============================] - ETA: 0s - loss: 0.3251 - acc: 0.8870

# %% [markdown]
# # 1000 에폭, 다시 데이터 증강하고

# %%
import os

import matplotlib.pyplot as plt
import numpy as np

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, Flatten, Dense, BatchNormalization, Conv2D, MaxPooling2D, Input
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications import efficientnet
from tensorflow.keras.applications import EfficientNetB2

preprocessor = efficientnet.preprocess_input

# conv_layers = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# conv_layers.trainable = True

model = keras.Sequential()

# model.add(conv_layers)
model.add(Input((224,224,3)))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Conv2D(32, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Conv2D(64, (3,3), padding='same'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(3, activation='softmax'))

import tensorflow
optimizer = tensorflow.keras.optimizers.Adam(learning_rate=0.0001*0.1)  # <-----------------------
# model.compile(loss='sparse_categorical_crossentropy', optimizer="RMSprop", metrics=['acc'])
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
model.summary()

BATCH_SIZE = 64

train_data_generator = ImageDataGenerator(
      rotation_range=10,  # <-----------------------
      width_shift_range=0.1,  # <-----------------------
      height_shift_range=0.1,  # <-----------------------
      horizontal_flip=True,  # <-----------------------
      vertical_flip=False,  # <-----------------------
      rescale=1/255.,
      # preprocessing_function=preprocessor 
).flow_from_directory(
      "glaucoma/train",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

valid_data_generator = ImageDataGenerator(
      rescale=1/255.
      # preprocessing_function=preprocessor 
).flow_from_directory(
      "glaucoma/valid",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)

test_data_generator = ImageDataGenerator(
      rescale=1/255., 
      # preprocessing_function=preprocessor
).flow_from_directory(
      "glaucoma/test",
      target_size=(224,224),
      batch_size=BATCH_SIZE,
      class_mode='sparse'
)


history = model.fit(
      train_data_generator,
      validation_data=valid_data_generator,
      epochs=1000
)


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()

plt.plot(history.history['loss'][50:])
plt.plot(history.history['val_loss'][50:])
plt.show()

plt.plot(history.history['acc'][50:])
plt.plot(history.history['val_acc'][50:])
plt.show()


loss, acc = model.evaluate(test_data_generator)
print("loss=", loss)
print("acc=", acc)



batch_x, batch_y = test_data_generator.next()
y_ = model.predict(batch_x)
predicted = np.argmax(y_, axis=-1)

plt.plot(batch_y[:100], "o")
plt.plot(predicted[:100], '.')
plt.show()


custom_labels = list(test_data_generator.class_indices.keys())
print("label category index =", batch_y[0])
print("predicted category index =", predicted[0])
print("predicted category name =", custom_labels[predicted[0]])
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_127 (Conv2D)         (None, 224, 224, 32)      896
#
#  conv2d_128 (Conv2D)         (None, 224, 224, 32)      9248
#
#  conv2d_129 (Conv2D)         (None, 224, 224, 32)      9248
#
#  max_pooling2d_45 (MaxPoolin  (None, 112, 112, 32)     0
#  g2D)
#
#  conv2d_130 (Conv2D)         (None, 112, 112, 32)      9248
#
#  conv2d_131 (Conv2D)         (None, 112, 112, 32)      9248
#
#  conv2d_132 (Conv2D)         (None, 112, 112, 32)      9248
#
#  max_pooling2d_46 (MaxPoolin  (None, 56, 56, 32)       0
#  g2D)
#
#  conv2d_133 (Conv2D)         (None, 56, 56, 64)        18496
#
#  conv2d_134 (Conv2D)         (None, 56, 56, 64)        36928
#
#  conv2d_135 (Conv2D)         (None, 56, 56, 64)        36928
#
#  max_pooling2d_47 (MaxPoolin  (None, 28, 28, 64)       0
#  g2D)
#
#  conv2d_136 (Conv2D)         (None, 28, 28, 64)        36928
#
#  conv2d_137 (Conv2D)         (None, 28, 28, 64)        36928
#
#  conv2d_138 (Conv2D)         (None, 28, 28, 64)        36928
#
#  max_pooling2d_48 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_139 (Conv2D)         (None, 14, 14, 64)        36928
#
#  conv2d_140 (Conv2D)         (None, 14, 14, 64)        36928
#
#  conv2d_141 (Conv2D)         (None, 14, 14, 64)        36928
#
#  max_pooling2d_49 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 3136)              0
#
#  dense_22 (Dense)            (None, 256)               803072
#
#  batch_normalization_11 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dense_23 (Dense)            (None, 3)                 771
#
# =================================================================
# Total params: 1,165,923
# Trainable params: 1,165,411
# Non-trainable params: 512
# _________________________________________________________________
# Found 1230 images belonging to 3 classes.
# Found 160 images belonging to 3 classes.
# Found 154 images belonging to 3 classes.
# Epoch 1/1000
# 20/20 [==============================] - 19s 890ms/step - loss: 0.8362 - acc: 0.6626 - val_loss: 1.0958 - val_acc: 0.3125
# Epoch 2/1000
# 20/20 [==============================] - 18s 875ms/step - loss: 0.6980 - acc: 0.7163 - val_loss: 1.0654 - val_acc: 0.3812
# Epoch 3/1000
# 20/20 [==============================] - 17s 870ms/step - loss: 0.6504 - acc: 0.7333 - val_loss: 1.0644 - val_acc: 0.4062
# Epoch 4/1000
# 20/20 [==============================] - 18s 873ms/step - loss: 0.6294 - acc: 0.7439 - val_loss: 1.0386 - val_acc: 0.6250
# Epoch 5/1000
# 20/20 [==============================] - 17s 865ms/step - loss: 0.6042 - acc: 0.7577 - val_loss: 1.0263 - val_acc: 0.6812
# Epoch 6/1000
# 20/20 [==============================] - 18s 874ms/step - loss: 0.5828 - acc: 0.7764 - val_loss: 1.0013 - val_acc: 0.6625
# Epoch 7/1000
# 20/20 [==============================] - 17s 869ms/step - loss: 0.5765 - acc: 0.7724 - val_loss: 1.0124 - val_acc: 0.6438
# Epoch 8/1000
# 20/20 [==============================] - 18s 875ms/step - loss: 0.5675 - acc: 0.7715 - val_loss: 0.9892 - val_acc: 0.6562
# Epoch 9/1000
# 20/20 [==============================] - 17s 869ms/step - loss: 0.5553 - acc: 0.7707 - val_loss: 0.9953 - val_acc: 0.6062
