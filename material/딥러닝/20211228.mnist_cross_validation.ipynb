# %% [markdown]
# # cross validation

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Input, Reshape

import time

# %%
(raw_train_x, raw_train_y), (raw_test_x, raw_test_y) = tf.keras.datasets.mnist.load_data()

raw_x = np.concatenate((raw_train_x, raw_test_x), axis=0)
raw_y = np.concatenate((raw_train_y, raw_test_y), axis=0)

x = raw_x/255.
y = raw_y

# %%
x = x[:1000]
y = y[:1000]

# %%
def build_model():  
  model = keras.Sequential()
  model.add(Input((28,28)))
  model.add(Reshape((28,28,1)))
  model.add(Conv2D(32, (3, 3), padding='same'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Conv2D(64, (3, 3), padding='same'))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(10, activation='relu'))
  model.add(Dense(10, activation='relu'))
  model.add(Dense(10, activation='softmax'))

  model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

  return model

# %%
fold_count = 5

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=fold_count, shuffle=True)

losses = []
acces = []

for train, test in kfold.split(x, y):

  model = build_model()

  history = model.fit(x[train], y[train], batch_size=32, epochs=10, validation_split=0.2)

  loss, acc = model.evaluate(x[test], y[test])
  print("loss =", loss)
  print("acc =", acc)
  losses.append(loss)
  acces.append(acc)
# Out:
# Epoch 1/10
# 20/20 [==============================] - 2s 41ms/step - loss: 2.2274 - accuracy: 0.1344 - val_loss: 2.0736 - val_accuracy: 0.1688
# Epoch 2/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9695 - accuracy: 0.2234 - val_loss: 1.8372 - val_accuracy: 0.2750
# Epoch 3/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.6815 - accuracy: 0.3531 - val_loss: 1.6240 - val_accuracy: 0.3812
# Epoch 4/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4126 - accuracy: 0.4609 - val_loss: 1.5483 - val_accuracy: 0.4437
# Epoch 5/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.2736 - accuracy: 0.5078 - val_loss: 1.3719 - val_accuracy: 0.5000
# Epoch 6/10
# 20/20 [==============================] - 0s 7ms/step - loss: 1.0461 - accuracy: 0.6391 - val_loss: 1.2806 - val_accuracy: 0.5250
# Epoch 7/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.9037 - accuracy: 0.6875 - val_loss: 1.1749 - val_accuracy: 0.6062
# Epoch 8/10
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7945 - accuracy: 0.7188 - val_loss: 1.2134 - val_accuracy: 0.6000
# Epoch 9/10
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6452 - accuracy: 0.7750 - val_loss: 1.1062 - val_accuracy: 0.6750
# Epoch 10/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5255 - accuracy: 0.8313 - val_loss: 1.0615 - val_accuracy: 0.7437
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7021 - accuracy: 0.7950
# loss = 0.7020858526229858
# acc = 0.7950000166893005
# Epoch 1/10
# 20/20 [==============================] - 1s 15ms/step - loss: 2.1811 - accuracy: 0.1734 - val_loss: 2.0309 - val_accuracy: 0.2500
# Epoch 2/10
# 20/20 [==============================] - 0s 7ms/step - loss: 1.9254 - accuracy: 0.2109 - val_loss: 1.8726 - val_accuracy: 0.3125
# Epoch 3/10
# 20/20 [==============================] - 0s 12ms/step - loss: 1.7446 - accuracy: 0.3016 - val_loss: 1.7108 - val_accuracy: 0.4062
# Epoch 4/10
# 20/20 [==============================] - 0s 8ms/step - loss: 1.5548 - accuracy: 0.3984 - val_loss: 1.5783 - val_accuracy: 0.4750
# Epoch 5/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3488 - accuracy: 0.4578 - val_loss: 1.4080 - val_accuracy: 0.5500
# Epoch 6/10
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1531 - accuracy: 0.5828 - val_loss: 1.2703 - val_accuracy: 0.5625
# Epoch 7/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.9729 - accuracy: 0.6453 - val_loss: 1.2075 - val_accuracy: 0.6062
# Epoch 8/10
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8288 - accuracy: 0.7344 - val_loss: 1.0566 - val_accuracy: 0.6500
# Epoch 9/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7380 - accuracy: 0.7469 - val_loss: 0.9973 - val_accuracy: 0.6375
# Epoch 10/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5812 - accuracy: 0.8109 - val_loss: 0.9586 - val_accuracy: 0.6938
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7198 - accuracy: 0.7700
# loss = 0.7197652459144592
# acc = 0.7699999809265137
# Epoch 1/10
# 20/20 [==============================] - 1s 16ms/step - loss: 2.2500 - accuracy: 0.1406 - val_loss: 2.1897 - val_accuracy: 0.1813
# Epoch 2/10
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1289 - accuracy: 0.2250 - val_loss: 2.1222 - val_accuracy: 0.1937
# Epoch 3/10
# 20/20 [==============================] - 0s 6ms/step - loss: 2.0255 - accuracy: 0.2484 - val_loss: 2.0181 - val_accuracy: 0.2375
# Epoch 4/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9018 - accuracy: 0.3125 - val_loss: 1.9097 - val_accuracy: 0.2625
# Epoch 5/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.7580 - accuracy: 0.3844 - val_loss: 1.7748 - val_accuracy: 0.4250
# Epoch 6/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.6252 - accuracy: 0.5047 - val_loss: 1.5810 - val_accuracy: 0.5437
# Epoch 7/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4685 - accuracy: 0.5734 - val_loss: 1.4736 - val_accuracy: 0.5813
# Epoch 8/10
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3749 - accuracy: 0.6125 - val_loss: 1.3787 - val_accuracy: 0.6125
# Epoch 9/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.2938 - accuracy: 0.6328 - val_loss: 1.3021 - val_accuracy: 0.6125
# Epoch 10/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.2172 - accuracy: 0.6453 - val_loss: 1.2272 - val_accuracy: 0.6438
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2627 - accuracy: 0.6600
# loss = 1.2627278566360474
# acc = 0.6600000262260437
# Epoch 1/10
# 20/20 [==============================] - 1s 15ms/step - loss: 2.1808 - accuracy: 0.2031 - val_loss: 2.0174 - val_accuracy: 0.2875
# Epoch 2/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8635 - accuracy: 0.3594 - val_loss: 1.6771 - val_accuracy: 0.5000
# Epoch 3/10
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5254 - accuracy: 0.4828 - val_loss: 1.3535 - val_accuracy: 0.5188
# Epoch 4/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.2405 - accuracy: 0.5641 - val_loss: 1.1177 - val_accuracy: 0.6250
# Epoch 5/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.0402 - accuracy: 0.6172 - val_loss: 0.9921 - val_accuracy: 0.6250
# Epoch 6/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.8873 - accuracy: 0.6484 - val_loss: 0.9216 - val_accuracy: 0.6625
# Epoch 7/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.7665 - accuracy: 0.6687 - val_loss: 0.8160 - val_accuracy: 0.7000
# Epoch 8/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6382 - accuracy: 0.7469 - val_loss: 0.7583 - val_accuracy: 0.7625
# Epoch 9/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5053 - accuracy: 0.8359 - val_loss: 0.6818 - val_accuracy: 0.7563
# Epoch 10/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4110 - accuracy: 0.8656 - val_loss: 0.5917 - val_accuracy: 0.7625
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8740 - accuracy: 0.7800
# loss = 0.874014675617218
# acc = 0.7799999713897705
# Epoch 1/10
# 20/20 [==============================] - 1s 15ms/step - loss: 2.2397 - accuracy: 0.1859 - val_loss: 2.0655 - val_accuracy: 0.2625
# Epoch 2/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.8654 - accuracy: 0.3125 - val_loss: 1.5702 - val_accuracy: 0.3938
# Epoch 3/10
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4942 - accuracy: 0.4609 - val_loss: 1.3648 - val_accuracy: 0.5063
# Epoch 4/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.3088 - accuracy: 0.5875 - val_loss: 1.2426 - val_accuracy: 0.6438
# Epoch 5/10
# 20/20 [==============================] - 0s 7ms/step - loss: 1.1542 - accuracy: 0.6797 - val_loss: 1.2874 - val_accuracy: 0.6062
# Epoch 6/10
# 20/20 [==============================] - 0s 6ms/step - loss: 1.0595 - accuracy: 0.7094 - val_loss: 1.1715 - val_accuracy: 0.6438
# Epoch 7/10
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9817 - accuracy: 0.7437 - val_loss: 1.0759 - val_accuracy: 0.7125
# Epoch 8/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.8834 - accuracy: 0.7844 - val_loss: 1.1963 - val_accuracy: 0.6562
# Epoch 9/10
# 20/20 [==============================] - 0s 6ms/step - loss: 0.8248 - accuracy: 0.8078 - val_loss: 0.9922 - val_accuracy: 0.7437
# Epoch 10/10
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7419 - accuracy: 0.8484 - val_loss: 1.0172 - val_accuracy: 0.7312
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0642 - accuracy: 0.7700
# loss = 1.0641902685165405
# acc = 0.7699999809265137

# %%
average_acc = sum(acces) / fold_count
print("average acc=", average_acc)
# Out:
# average acc= 0.7549999952316284
